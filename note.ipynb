# %%
import pandas as pd
df=pd.read_parquet("data/processed/raw_data.parquet")
df.head()
# Out:
#    step    type      amount    category nameOrig nameDest  oldbalanceOrg  \
# 0     0   DEBIT  298.842041       Other    C8083    C7053  455489.321571
# 1     0   DEBIT   93.087916  Recreation    C5575    C1117  229508.291214
# 2     0  EFTPOS  155.644864  Healthcare    C1549    C1423  202568.806856
# 3     0    BPAY  299.759073        Food    C7435    C6390  491560.600203
# 4     0   DEBIT  173.715615       Other    C8083    C5946  455190.479531
#
#    newbalanceOrig  isFraud  isMoneyLaundering laundering_typology  \
# 0   455190.479531        0                  0              normal
# 1   229415.203298        0                  0              normal
# 2   202413.161992        0                  0              normal
# 3   491260.841131        0                  0              normal
# 4   455016.763916        0                  0              normal
#
#                                             metadata  fraud_probability  hour  \
# ...

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'category', 'nameOrig', 'nameDest',
#        'oldbalanceOrg', 'newbalanceOrig', 'isFraud', 'isMoneyLaundering',
#        'laundering_typology', 'metadata', 'fraud_probability', 'hour',
#        'day_of_week', 'day_of_month', 'month'],
#       dtype='object')

# %%
#Created a sample file
# Chargé 300k lignes dans prefect pour l'orchestration

Après redémarrage
Ouvrez à nouveau PowerShell en administrateur, puis :

powershell
dism.exe /online /enable-feature /featurename:Microsoft-Windows-Subsystem-Linux /all /norestart
powershell
dism.exe /online /enable-feature /featurename:VirtualMachinePlatform /all /norestart
powershell
Restart-Computer
Deuxième redémarrage
Ouvrez PowerShell en administrateur, puis :

powershell
wsl --update
powershell
wsl --set-default-version 2
powershell
wsl --status

docker compose build fraud-api

# %%
docker exec -it fraudguard-postgres psql -U fraudguard -d fraudguard_db -c "
CREATE TABLE IF NOT EXISTS audit_log (
    id SERIAL PRIMARY KEY,
    timestamp TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    transaction_id BIGINT,
    transaction_json JSONB,
    fraud_probability FLOAT,
    top_factors JSONB,
    shap_values JSONB,
    explanation TEXT,
    decision VARCHAR(50),
    audit_log JSONB,
    latency_ml FLOAT,
    latency_agent FLOAT
);"

# %%
{
  "transaction_id": 1002,
  "transaction": {
    "step": 12,
    "type": "PAYMENT",
    "amount": 45.20,
    "category": "Retail",
    "hour": 14,
    "day_of_week": 2,
    "day_of_month": 15,
    "month": 5
  }
}
