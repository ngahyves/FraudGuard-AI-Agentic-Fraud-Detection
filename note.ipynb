# %%
# Data table for saving API results
docker exec -it fraudguard-postgres psql -U fraudguard -d fraudguard_db -c "
CREATE TABLE IF NOT EXISTS audit_log (
    id SERIAL PRIMARY KEY,
    timestamp TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    transaction_id BIGINT,
    transaction_json JSONB,
    fraud_probability FLOAT,
    top_factors JSONB,
    shap_values JSONB,
    explanation TEXT,
    decision VARCHAR(50),
    audit_log JSONB,
    latency_ml FLOAT,
    latency_agent FLOAT
);"

# %%
# Transaction example
{
  "transaction_id": 1002,
  "transaction": {
    "step": 12,
    "type": "PAYMENT",
    "amount": 45.20,
    "category": "Retail",
    "hour": 14,
    "day_of_week": 2,
    "day_of_month": 15,
    "month": 5
  }
}

# %% [markdown]
# # Neon url
# postgresql://neondb_owner:npg_zC5sEeOZJ4wX@ep-jolly-dream-aqshzo1h-pooler.c-8.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require

# %% [markdown]
# docker volume prune -f
# docker builder prune -f
